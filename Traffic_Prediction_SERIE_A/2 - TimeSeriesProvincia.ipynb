# %%
import pandas as pd
import numpy as np
from plotly import tools
import plotly.graph_objs as go

# %run ../../UtilityPython.ipynb
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def plot_time_series_traffic(df, prov):
    df_prov = df[df['PROVINCIA']==prov]
    df_prov.drop('PROVINCIA', axis=1, inplace=True)
    df_prov.set_index('DATA',inplace=True)
    df_prov=df_prov.asfreq('3H').reset_index()
    df_prov.set_index('DATA',inplace=True)
    dfprov = df[df['PROVINCIA']==prov]
    dfprov['DATA']=pd.DatetimeIndex(dfprov['DATA'])
    dfprov.drop('PROVINCIA', axis=1, inplace=True)
    dfprov.set_index('DATA',inplace=True)
    df_final=pd.merge(dfprov, df_prov['TIPO_GIORNO_DS'], left_index=True, right_index=True, how='outer')
    df_final.drop('TIPO_GIORNO_DS_y', axis=1, inplace=True)
    df_final.rename(columns={'TIPO_GIORNO_DS_x' : 'TIPO_GIORNO_DS'}, inplace=True)
    df_final[['MAX_DS','SOPRA_SOGLIA_GIALLA','SOPRA_SOGLIA_ROSSA', 'SOPRA_CAPACITA', 'N_APPARATI','KPI']
            ]=df_final[['MAX_DS','SOPRA_SOGLIA_GIALLA','SOPRA_SOGLIA_ROSSA', 'SOPRA_CAPACITA',
                        'N_APPARATI','KPI']].fillna(0)
    
    trace1 = go.Scatter(x = df_final.index, y = df_final.MAX_DS, name = "MAX_DS", line = dict(color = '#17BECF'), opacity = 0.8)
    trace2 = go.Scatter(x = df_final.index ,y = df_final.KPI, name = "KPI", line = dict(color = '#7F7F7F'), opacity = 0.8)

    fig = tools.make_subplots(rows=2, cols=1, specs=[[{}], [{}]], shared_xaxes=True,  shared_yaxes=True)

    fig.append_trace(trace1, 1,1)
    fig.append_trace(trace2, 2,1)

    fig['layout'].update( height=900,title='Time Series Max_DS / KPI provincia di ' + prov, showlegend=False)

    fig.show()

# %%
df = pd.read_csv('./datasets/to_train.csv', keep_default_na=False, na_values=['_'])
df.drop('REGIONE',axis=1,inplace=True)

plot_time_series_traffic(df,'RM')
# Out:
# C:\Users\ant.pagano\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="134cb060-bfb8-4050-aca6-b5bfe7d7bcf2" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("134cb060-bfb8-4050-aca6-b5bfe7d7bcf2")) {
#                     Plotly.newPlot(
#                         '134cb060-bfb8-4050-aca6-b5bfe7d7bcf2',
# ...

# %%
plot_time_series_traffic(df,'NA')
#SU DAZN Domenica 27 ottobre 2019, ore 15.00, SPAL-NAPOLI
#Sabato 9 novembre 2019, ore 20.45, NAPOLI-GENOA
#Sabato 18 gennaio 2020, ore 20.45, NAPOLI-FIORENTINA
#27 Novembre, ore 20.45 LIVERPOOL - NAPOLI
# Out:
# C:\Users\ant.pagano\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="3bfd49d7-2a44-47f7-aec7-4c0a02d18785" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3bfd49d7-2a44-47f7-aec7-4c0a02d18785")) {
#                     Plotly.newPlot(
#                         '3bfd49d7-2a44-47f7-aec7-4c0a02d18785',
# ...

# %%
plot_time_series_traffic(df,'MI')
# Out:
# C:\Users\ant.pagano\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>
#
#
#             <div id="8940638e-17ea-4132-b6ec-d27b8ef724c8" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8940638e-17ea-4132-b6ec-d27b8ef724c8")) {
#                     Plotly.newPlot(
#                         '8940638e-17ea-4132-b6ec-d27b8ef724c8',
# ...
