# %%
import pandas as pd
import numpy as np
from plotly import tools

# %run ../../UtilityPython.ipynb
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('./datasets/final_dataset_v2.csv')
df.tail()
# Out:
#                                                ID PROVINCIA        DATA  \
# 177680       FORLITBK-100DIRETTI_IPMD11RN02/1/0/2        FC  26-01-2020
# 177681   ARONITAF-100DIRETTI_IPRGAVB001/100/0/0/5        NO  26-01-2020
# 177682         MIRRITAA-100DIRETTI_IPRG-VE013/9/3        VE  26-01-2020
# 177683   MESSITAF-100DIRETTI_IPRGAME003/100/0/0/2        ME  26-01-2020
# 177684  CEVAITAC-100DIRETTI_IPRGACN005/103/0/0/20        CN  26-01-2020
#
#         CAPACITA  SOGLIA GIALLA  SOGLIA ROSSA    MAX_DS INTERVALLO_MAX_DS  \
# 177680    1000.0          800.0         900.0   39.5390             14:45
# 177681     450.0          360.0         405.0  266.5661             21:00
# 177682     450.0          360.0         405.0  223.6706             22:00
# 177683     450.0          360.0         405.0  305.0565             15:30
# 177684     450.0          360.0         405.0   16.1194             13:00
#
#        TIPO_GIORNO_DS
# 177680            FES
# 177681            FES
# 177682            FES
# 177683            FES
# 177684            FES

# %%
df.groupby('DATA').size().to_frame('size').reset_index().sort_values(['DATA', 'size'], ascending=[True, False])
# Out:
#           DATA  size
# 0   01-01-2020  5100
# 1   02-01-2020  5086
# 2   03-01-2020  5130
# 3   04-01-2020  5114
# 4   05-01-2020  5122
# 5   06-01-2020  5188
# 6   07-01-2020  4914
# 7   08-01-2020  4908
# 8   09-01-2020  4896
# 9   10-01-2020  4921
# 10  11-01-2020  5113
# 11  12-01-2020  5117
# 12  13-01-2020  4654
# 13  14-01-2020  5826
# 14  15-01-2020  4975
# 15  16-01-2020  4949
# 16  17-01-2020  4980
# 17  18-01-2020  5151
# 18  19-01-2020  5179
# 19  20-01-2020  4976
# 20  21-01-2020  4955
# 21  22-01-2020  4987
# 22  23-01-2020  4992
# 23  23-12-2019  5094
# 24  24-01-2020  5031
# 25  24-12-2019  5131
# 26  25-01-2020  5225
# 27  25-12-2019  5076
# 28  26-01-2020  5235
# 29  26-12-2019  5146
# 30  27-12-2019  5157
# 31  28-12-2019  5127
# 32  29-12-2019  5043
# 33  30-12-2019  5129
# 34  31-12-2019  5058

# %%
import datetime
#Aggregazione per DATA, aggregato a 3 ore, per PROVINCIA.
#Vediamo l'andamento della somma dei picchi (sum MAX_DS)
#.dt.strftime('%d-%m-%Y')
df.loc[:,'DATA'] = pd.to_datetime(df.DATA + ' ' + df.INTERVALLO_MAX_DS, format="%d-%m-%Y %H:%M")
df_f=df.groupby(['DATA', 'PROVINCIA'], as_index=False).agg({'MAX_DS': "sum"})
df_f.set_index('DATA',inplace=True)
df_f.tail()
# Out:
#                     PROVINCIA   MAX_DS
# DATA
# 2020-01-26 23:45:00        SR  45.4287
# 2020-01-26 23:45:00        TO  71.2253
# 2020-01-26 23:45:00        UD   6.0009
# 2020-01-26 23:45:00        VA  40.0217
# 2020-01-26 23:45:00        VI  25.9858

# %%
df_rm_week1=df_f[(df_f.PROVINCIA=='RM') & (df_f.index>='2019-12-23 00:00') & (df_f.index<='2019-12-29 23:45')]
df_rm_3H_week1 = df_rm_week1['MAX_DS'].resample('3H').sum()

df_rm_week2=df_f[(df_f.PROVINCIA=='RM') & (df_f.index>='2019-12-30 00:00') & (df_f.index<='2020-01-05 23:45')]
df_rm_3H_week2 = df_rm_week2['MAX_DS'].resample('3H').sum()

df_rm_week3=df_f[(df_f.PROVINCIA=='RM') & (df_f.index>='2020-01-06 00:00') & (df_f.index<='2020-01-12 23:45')]
df_rm_3H_week3 = df_rm_week3['MAX_DS'].resample('3H').sum()

df_rm_week4=df_f[(df_f.PROVINCIA=='RM') & (df_f.index>='2020-01-13 00:00') & (df_f.index<='2020-01-19 23:45')]
df_rm_3H_week4 = df_rm_week4['MAX_DS'].resample('3H').sum()

df_rm_week5=df_f[(df_f.PROVINCIA=='RM') & (df_f.index>='2020-01-20 00:00') & (df_f.index<='2020-01-26 23:45')]
df_rm_3H_week5 = df_rm_week5['MAX_DS'].resample('3H').sum()

# %%
import plotly.graph_objs as go

#time series by 3 hours
trace1 = go.Scatter(x = df_rm_3H_week1.index, y = df_rm_3H_week1, name = "SUM(MAX_DS)", line = dict(color = '#17BECF'), opacity = 0.8)
trace2 = go.Scatter(x = df_rm_3H_week2.index ,y = df_rm_3H_week2, name = "SUM(MAX_DS)", line = dict(color = '#7F7F7F'), opacity = 0.8)
trace3 = go.Scatter(x = df_rm_3H_week3.index ,y = df_rm_3H_week3, name = "SUM(MAX_DS)", line = dict(color ='#32CD32'), opacity = 0.8)
trace4 = go.Scatter(x = df_rm_3H_week4.index ,y = df_rm_3H_week4, name = "SUM(MAX_DS)", line = dict(color ='#AD9B0C'), opacity = 0.8)
trace5 = go.Scatter(x = df_rm_3H_week5.index ,y = df_rm_3H_week5, name = "SUM(MAX_DS)", line = dict(color ='#B22222'), opacity = 0.8)

fig = tools.make_subplots(rows=5, cols=1, specs=[[{}], [{}], [{}], [{}], [{}]])

fig.append_trace(trace1, 1,1)
fig.append_trace(trace2, 2,1)
fig.append_trace(trace3, 3,1)
fig.append_trace(trace4, 4,1)
fig.append_trace(trace5, 5,1)

fig['layout'].update( height=900,title='Time Series Max_DS provincia di RM', showlegend=False)

fig.show()
# Out:
# <div>
#
#
#             <div id="989cfac7-14ce-4e35-ab05-f27316a506ab" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("989cfac7-14ce-4e35-ab05-f27316a506ab")) {
#                     Plotly.newPlot(
#                         '989cfac7-14ce-4e35-ab05-f27316a506ab',
#                         [{"line": {"color": "#17BECF"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-23T00:00:00", "2019-12-23T03:00:00", "2019-12-23T06:00:00", "2019-12-23T09:00:00", "2019-12-23T12:00:00", "2019-12-23T15:00:00", "2019-12-23T18:00:00", "2019-12-23T21:00:00", "2019-12-24T00:00:00", "2019-12-24T03:00:00", "2019-12-24T06:00:00", "2019-12-24T09:00:00", "2019-12-24T12:00:00", "2019-12-24T15:00:00", "2019-12-24T18:00:00", "2019-12-24T21:00:00", "2019-12-25T00:00:00", "2019-12-25T03:00:00", "2019-12-25T06:00:00", "2019-12-25T09:00:00", "2019-12-25T12:00:00", "2019-12-25T15:00:00", "2019-12-25T18:00:00", "2019-12-25T21:00:00", "2019-12-26T00:00:00", "2019-12-26T03:00:00", "2019-12-26T06:00:00", "2019-12-26T09:00:00", "2019-12-26T12:00:00", "2019-12-26T15:00:00", "2019-12-26T18:00:00", "2019-12-26T21:00:00", "2019-12-27T00:00:00", "2019-12-27T03:00:00", "2019-12-27T06:00:00", "2019-12-27T09:00:00", "2019-12-27T12:00:00", "2019-12-27T15:00:00", "2019-12-27T18:00:00", "2019-12-27T21:00:00", "2019-12-28T00:00:00", "2019-12-28T03:00:00", "2019-12-28T06:00:00", "2019-12-28T09:00:00", "2019-12-28T12:00:00", "2019-12-28T15:00:00", "2019-12-28T18:00:00", "2019-12-28T21:00:00", "2019-12-29T00:00:00", "2019-12-29T03:00:00", "2019-12-29T06:00:00", "2019-12-29T09:00:00", "2019-12-29T12:00:00", "2019-12-29T15:00:00", "2019-12-29T18:00:00", "2019-12-29T21:00:00"], "xaxis": "x", "y": [1831.6012999999998, 0.0, 12.9277, 188.8349, 1056.9575, 2079.8663, 2770.1851000000006, 34377.472, 3108.3730000000005, 0.0, 12.8238, 258.9006, 4154.9007, 21445.716700000004, 7127.6026, 461.8409, 257.1188, 13.6011, 30.4711, 792.7456, 277.7643, 974.9151999999999, 9109.9066, 28094.8008, 2070.7502, 0.0, 0.0, 353.2179, 737.2382, 4116.3148, 7420.295500000002, 28516.6968, 1241.2469, 0.0, 0.0, 174.3407, 436.44140000000004, 3050.1695999999997, 4967.225, 34591.2627, 962.5110000000001, 0.0, 0.0, 60.0723, 1547.9965, 4008.5322000000006, 6441.6799, 29922.689400000003, 381.2007, 0.0, 0.0, 119.8973, 555.0296999999999, 4963.915800000001, 5090.144399999999, 35124.225399999996], "yaxis": "y"}, {"line": {"color": "#7F7F7F"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-30T00:00:00", "2019-12-30T03:00:00", "2019-12-30T06:00:00", "2019-12-30T09:00:00", "2019-12-30T12:00:00", "2019-12-30T15:00:00", "2019-12-30T18:00:00", "2019-12-30T21:00:00", "2019-12-31T00:00:00", "2019-12-31T03:00:00", "2019-12-31T06:00:00", "2019-12-31T09:00:00", "2019-12-31T12:00:00", "2019-12-31T15:00:00", "2019-12-31T18:00:00", "2019-12-31T21:00:00", "2020-01-01T00:00:00", "2020-01-01T03:00:00", "2020-01-01T06:00:00", "2020-01-01T09:00:00", "2020-01-01T12:00:00", "2020-01-01T15:00:00", "2020-01-01T18:00:00", "2020-01-01T21:00:00", "2020-01-02T00:00:00", "2020-01-02T03:00:00", "2020-01-02T06:00:00", "2020-01-02T09:00:00", "2020-01-02T12:00:00", "2020-01-02T15:00:00", "2020-01-02T18:00:00", "2020-01-02T21:00:00", "2020-01-03T00:00:00", "2020-01-03T03:00:00", "2020-01-03T06:00:00", "2020-01-03T09:00:00", "2020-01-03T12:00:00", "2020-01-03T15:00:00", "2020-01-03T18:00:00", "2020-01-03T21:00:00", "2020-01-04T00:00:00", "2020-01-04T03:00:00", "2020-01-04T06:00:00", "2020-01-04T09:00:00", "2020-01-04T12:00:00", "2020-01-04T15:00:00", "2020-01-04T18:00:00", "2020-01-04T21:00:00", "2020-01-05T00:00:00", "2020-01-05T03:00:00", "2020-01-05T06:00:00", "2020-01-05T09:00:00", "2020-01-05T12:00:00", "2020-01-05T15:00:00", "2020-01-05T18:00:00", "2020-01-05T21:00:00"], "xaxis": "x2", "y": [1090.4379, 0.0, 0.0, 129.2889, 784.4291999999999, 1757.7134, 1905.4716, 39464.5956, 7550.315, 0.0, 0.0, 320.4318, 4365.9234, 18182.8972, 5603.400999999999, 76.6886, 0.0, 0.0, 0.0, 132.6029, 255.78430000000003, 2184.5786, 9219.550099999999, 33701.8626, 655.9341000000001, 21.1021, 0.0, 187.0277, 578.1474000000001, 1209.2426, 3694.7391999999995, 39175.859399999994, 1399.3461, 0.0, 0.0, 25.9556, 516.0391999999999, 1466.0389000000002, 3403.5420999999997, 37564.8833, 1435.3415, 0.0, 0. ...

# %%
#Domenica 5 gennaio 2020, ore 20.45, ROMA-TORINO

fig1 = tools.make_subplots(rows=1, cols=1, specs=[[{}]])

fig1.append_trace(trace1, 1,1)
fig1.append_trace(trace2, 1,1)
fig1.append_trace(trace3, 1,1)
fig1.append_trace(trace4, 1,1)
fig1.append_trace(trace5, 1,1)

fig1['layout'].update( height=900,title='Time Series Max_DS provincia di RM', showlegend=False)

fig1.show()
# Out:
# <div>
#
#
#             <div id="84b72242-e8a8-409d-bbbe-c9d68b111185" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("84b72242-e8a8-409d-bbbe-c9d68b111185")) {
#                     Plotly.newPlot(
#                         '84b72242-e8a8-409d-bbbe-c9d68b111185',
#                         [{"line": {"color": "#17BECF"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-23T00:00:00", "2019-12-23T03:00:00", "2019-12-23T06:00:00", "2019-12-23T09:00:00", "2019-12-23T12:00:00", "2019-12-23T15:00:00", "2019-12-23T18:00:00", "2019-12-23T21:00:00", "2019-12-24T00:00:00", "2019-12-24T03:00:00", "2019-12-24T06:00:00", "2019-12-24T09:00:00", "2019-12-24T12:00:00", "2019-12-24T15:00:00", "2019-12-24T18:00:00", "2019-12-24T21:00:00", "2019-12-25T00:00:00", "2019-12-25T03:00:00", "2019-12-25T06:00:00", "2019-12-25T09:00:00", "2019-12-25T12:00:00", "2019-12-25T15:00:00", "2019-12-25T18:00:00", "2019-12-25T21:00:00", "2019-12-26T00:00:00", "2019-12-26T03:00:00", "2019-12-26T06:00:00", "2019-12-26T09:00:00", "2019-12-26T12:00:00", "2019-12-26T15:00:00", "2019-12-26T18:00:00", "2019-12-26T21:00:00", "2019-12-27T00:00:00", "2019-12-27T03:00:00", "2019-12-27T06:00:00", "2019-12-27T09:00:00", "2019-12-27T12:00:00", "2019-12-27T15:00:00", "2019-12-27T18:00:00", "2019-12-27T21:00:00", "2019-12-28T00:00:00", "2019-12-28T03:00:00", "2019-12-28T06:00:00", "2019-12-28T09:00:00", "2019-12-28T12:00:00", "2019-12-28T15:00:00", "2019-12-28T18:00:00", "2019-12-28T21:00:00", "2019-12-29T00:00:00", "2019-12-29T03:00:00", "2019-12-29T06:00:00", "2019-12-29T09:00:00", "2019-12-29T12:00:00", "2019-12-29T15:00:00", "2019-12-29T18:00:00", "2019-12-29T21:00:00"], "xaxis": "x", "y": [1831.6012999999998, 0.0, 12.9277, 188.8349, 1056.9575, 2079.8663, 2770.1851000000006, 34377.472, 3108.3730000000005, 0.0, 12.8238, 258.9006, 4154.9007, 21445.716700000004, 7127.6026, 461.8409, 257.1188, 13.6011, 30.4711, 792.7456, 277.7643, 974.9151999999999, 9109.9066, 28094.8008, 2070.7502, 0.0, 0.0, 353.2179, 737.2382, 4116.3148, 7420.295500000002, 28516.6968, 1241.2469, 0.0, 0.0, 174.3407, 436.44140000000004, 3050.1695999999997, 4967.225, 34591.2627, 962.5110000000001, 0.0, 0.0, 60.0723, 1547.9965, 4008.5322000000006, 6441.6799, 29922.689400000003, 381.2007, 0.0, 0.0, 119.8973, 555.0296999999999, 4963.915800000001, 5090.144399999999, 35124.225399999996], "yaxis": "y"}, {"line": {"color": "#7F7F7F"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-30T00:00:00", "2019-12-30T03:00:00", "2019-12-30T06:00:00", "2019-12-30T09:00:00", "2019-12-30T12:00:00", "2019-12-30T15:00:00", "2019-12-30T18:00:00", "2019-12-30T21:00:00", "2019-12-31T00:00:00", "2019-12-31T03:00:00", "2019-12-31T06:00:00", "2019-12-31T09:00:00", "2019-12-31T12:00:00", "2019-12-31T15:00:00", "2019-12-31T18:00:00", "2019-12-31T21:00:00", "2020-01-01T00:00:00", "2020-01-01T03:00:00", "2020-01-01T06:00:00", "2020-01-01T09:00:00", "2020-01-01T12:00:00", "2020-01-01T15:00:00", "2020-01-01T18:00:00", "2020-01-01T21:00:00", "2020-01-02T00:00:00", "2020-01-02T03:00:00", "2020-01-02T06:00:00", "2020-01-02T09:00:00", "2020-01-02T12:00:00", "2020-01-02T15:00:00", "2020-01-02T18:00:00", "2020-01-02T21:00:00", "2020-01-03T00:00:00", "2020-01-03T03:00:00", "2020-01-03T06:00:00", "2020-01-03T09:00:00", "2020-01-03T12:00:00", "2020-01-03T15:00:00", "2020-01-03T18:00:00", "2020-01-03T21:00:00", "2020-01-04T00:00:00", "2020-01-04T03:00:00", "2020-01-04T06:00:00", "2020-01-04T09:00:00", "2020-01-04T12:00:00", "2020-01-04T15:00:00", "2020-01-04T18:00:00", "2020-01-04T21:00:00", "2020-01-05T00:00:00", "2020-01-05T03:00:00", "2020-01-05T06:00:00", "2020-01-05T09:00:00", "2020-01-05T12:00:00", "2020-01-05T15:00:00", "2020-01-05T18:00:00", "2020-01-05T21:00:00"], "xaxis": "x", "y": [1090.4379, 0.0, 0.0, 129.2889, 784.4291999999999, 1757.7134, 1905.4716, 39464.5956, 7550.315, 0.0, 0.0, 320.4318, 4365.9234, 18182.8972, 5603.400999999999, 76.6886, 0.0, 0.0, 0.0, 132.6029, 255.78430000000003, 2184.5786, 9219.550099999999, 33701.8626, 655.9341000000001, 21.1021, 0.0, 187.0277, 578.1474000000001, 1209.2426, 3694.7391999999995, 39175.859399999994, 1399.3461, 0.0, 0.0, 25.9556, 516.0391999999999, 1466.0389000000002, 3403.5420999999997, 37564.8833, 1435.3415, 0.0, 0.0 ...

# %%
df_mi_week1=df_f[(df_f.PROVINCIA=='MI') & (df_f.index>='2019-12-23 00:00') & (df_f.index<='2019-12-29 23:45')]
df_mi_3H_week1 = df_mi_week1['MAX_DS'].resample('3H').sum()

df_mi_week2=df_f[(df_f.PROVINCIA=='MI') & (df_f.index>='2019-12-30 00:00') & (df_f.index<='2020-01-05 23:45')]
df_mi_3H_week2 = df_mi_week2['MAX_DS'].resample('3H').sum()

df_mi_week3=df_f[(df_f.PROVINCIA=='MI') & (df_f.index>='2020-01-06 00:00') & (df_f.index<='2020-01-12 23:45')]
df_mi_3H_week3 = df_mi_week3['MAX_DS'].resample('3H').sum()

df_mi_week4=df_f[(df_f.PROVINCIA=='MI') & (df_f.index>='2020-01-13 00:00') & (df_f.index<='2020-01-19 23:45')]
df_mi_3H_week4 = df_mi_week4['MAX_DS'].resample('3H').sum()

df_mi_week5=df_f[(df_f.PROVINCIA=='MI') & (df_f.index>='2020-01-20 00:00') & (df_f.index<='2020-01-26 23:45')]
df_mi_3H_week5 = df_mi_week5['MAX_DS'].resample('3H').sum()

# %%
#Inter-Atalanta  11/01/2020 20:45
#Domenica 19 gennaio 2020, ore 12.30, MILAN-UDINESE
#Domenica 26 gennaio 2020, ore 12.30, INTER-CAGLIARI

#time series by 3 hours
trace1 = go.Scatter(x = df_mi_3H_week1.index, y = df_mi_3H_week1, name = "SUM(MAX_DS)", line = dict(color = '#17BECF'), opacity = 0.8)
trace2 = go.Scatter(x = df_mi_3H_week2.index ,y = df_mi_3H_week2, name = "SUM(MAX_DS)", line = dict(color = '#7F7F7F'), opacity = 0.8)
trace3 = go.Scatter(x = df_mi_3H_week3.index ,y = df_mi_3H_week3, name = "SUM(MAX_DS)", line = dict(color ='#32CD32'), opacity = 0.8)
trace4 = go.Scatter(x = df_mi_3H_week4.index ,y = df_mi_3H_week4, name = "SUM(MAX_DS)", line = dict(color ='#AD9B0C'), opacity = 0.8)
trace5 = go.Scatter(x = df_mi_3H_week5.index ,y = df_mi_3H_week5, name = "SUM(MAX_DS)", line = dict(color ='#B22222'), opacity = 0.8)

fig = tools.make_subplots(rows=5, cols=1, specs=[[{}], [{}], [{}], [{}], [{}]])

fig.append_trace(trace1, 1,1)
fig.append_trace(trace2, 2,1)
fig.append_trace(trace3, 3,1)
fig.append_trace(trace4, 4,1)
fig.append_trace(trace5, 5,1)

fig['layout'].update( height=900,title='Time Series Max_DS provincia di MI', showlegend=False)

fig.show()
# Out:
# <div>
#
#
#             <div id="80c7924f-09e4-4cbf-acef-f64600543c5e" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("80c7924f-09e4-4cbf-acef-f64600543c5e")) {
#                     Plotly.newPlot(
#                         '80c7924f-09e4-4cbf-acef-f64600543c5e',
#                         [{"line": {"color": "#17BECF"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-23T00:00:00", "2019-12-23T03:00:00", "2019-12-23T06:00:00", "2019-12-23T09:00:00", "2019-12-23T12:00:00", "2019-12-23T15:00:00", "2019-12-23T18:00:00", "2019-12-23T21:00:00", "2019-12-24T00:00:00", "2019-12-24T03:00:00", "2019-12-24T06:00:00", "2019-12-24T09:00:00", "2019-12-24T12:00:00", "2019-12-24T15:00:00", "2019-12-24T18:00:00", "2019-12-24T21:00:00", "2019-12-25T00:00:00", "2019-12-25T03:00:00", "2019-12-25T06:00:00", "2019-12-25T09:00:00", "2019-12-25T12:00:00", "2019-12-25T15:00:00", "2019-12-25T18:00:00", "2019-12-25T21:00:00", "2019-12-26T00:00:00", "2019-12-26T03:00:00", "2019-12-26T06:00:00", "2019-12-26T09:00:00", "2019-12-26T12:00:00", "2019-12-26T15:00:00", "2019-12-26T18:00:00", "2019-12-26T21:00:00", "2019-12-27T00:00:00", "2019-12-27T03:00:00", "2019-12-27T06:00:00", "2019-12-27T09:00:00", "2019-12-27T12:00:00", "2019-12-27T15:00:00", "2019-12-27T18:00:00", "2019-12-27T21:00:00", "2019-12-28T00:00:00", "2019-12-28T03:00:00", "2019-12-28T06:00:00", "2019-12-28T09:00:00", "2019-12-28T12:00:00", "2019-12-28T15:00:00", "2019-12-28T18:00:00", "2019-12-28T21:00:00", "2019-12-29T00:00:00", "2019-12-29T03:00:00", "2019-12-29T06:00:00", "2019-12-29T09:00:00", "2019-12-29T12:00:00", "2019-12-29T15:00:00", "2019-12-29T18:00:00", "2019-12-29T21:00:00"], "xaxis": "x", "y": [520.1049, 9.8933, 0.0, 102.8237, 1638.4983, 949.3467, 2545.6805, 26665.572500000002, 3306.0874999999996, 0.0, 30.3979, 222.3551, 4901.034099999999, 8146.9801, 4628.405199999999, 6562.3637, 407.5237, 0.0, 19.2472, 397.90430000000003, 105.2313, 386.1083, 4697.1024, 24798.825599999996, 1278.7666, 0.0, 0.0, 149.5949, 1505.8585, 2618.0574, 8584.5907, 19227.1232, 897.0500000000001, 0.0, 0.0, 671.9388, 2038.8078999999998, 2799.2914, 2714.4844000000003, 23457.400999999998, 551.6479, 0.0, 0.0, 0.0, 1051.3091, 2510.7911, 2846.3352999999997, 24502.1371, 1768.9321, 0.0, 0.0, 93.1945, 1957.6602000000003, 2930.1028000000006, 4899.839, 21283.9902], "yaxis": "y"}, {"line": {"color": "#7F7F7F"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-30T00:00:00", "2019-12-30T03:00:00", "2019-12-30T06:00:00", "2019-12-30T09:00:00", "2019-12-30T12:00:00", "2019-12-30T15:00:00", "2019-12-30T18:00:00", "2019-12-30T21:00:00", "2019-12-31T00:00:00", "2019-12-31T03:00:00", "2019-12-31T06:00:00", "2019-12-31T09:00:00", "2019-12-31T12:00:00", "2019-12-31T15:00:00", "2019-12-31T18:00:00", "2019-12-31T21:00:00", "2020-01-01T00:00:00", "2020-01-01T03:00:00", "2020-01-01T06:00:00", "2020-01-01T09:00:00", "2020-01-01T12:00:00", "2020-01-01T15:00:00", "2020-01-01T18:00:00", "2020-01-01T21:00:00", "2020-01-02T00:00:00", "2020-01-02T03:00:00", "2020-01-02T06:00:00", "2020-01-02T09:00:00", "2020-01-02T12:00:00", "2020-01-02T15:00:00", "2020-01-02T18:00:00", "2020-01-02T21:00:00", "2020-01-03T00:00:00", "2020-01-03T03:00:00", "2020-01-03T06:00:00", "2020-01-03T09:00:00", "2020-01-03T12:00:00", "2020-01-03T15:00:00", "2020-01-03T18:00:00", "2020-01-03T21:00:00", "2020-01-04T00:00:00", "2020-01-04T03:00:00", "2020-01-04T06:00:00", "2020-01-04T09:00:00", "2020-01-04T12:00:00", "2020-01-04T15:00:00", "2020-01-04T18:00:00", "2020-01-04T21:00:00", "2020-01-05T00:00:00", "2020-01-05T03:00:00", "2020-01-05T06:00:00", "2020-01-05T09:00:00", "2020-01-05T12:00:00", "2020-01-05T15:00:00", "2020-01-05T18:00:00", "2020-01-05T21:00:00"], "xaxis": "x2", "y": [1016.8185, 332.1583, 0.0, 0.0, 747.8939999999999, 1104.7071, 3012.9500000000003, 24883.840100000005, 7922.9430999999995, 0.0, 0.0, 92.2235, 4027.5224999999996, 9109.752700000001, 3360.3019, 611.0487, 306.935, 0.0, 0.0, 25.4368, 214.75100000000003, 3578.3886, 4971.4747, 23820.771599999996, 832.0942, 0.0, 0.0, 18.3433, 628.6456, 1303.429, 4151.1053, 25510.943600000002, 304.4262, 0.0, 0.0, 0.0, 781.5186, 568.5023, 4309.827399999999, 27007.995000000003, 1438.7325, 0.0, 0.0, 72.00800000000001, 1039.8916000000 ...

# %%
fig1 = tools.make_subplots(rows=1, cols=1, specs=[[{}]])

fig1.append_trace(trace1, 1,1)
fig1.append_trace(trace2, 1,1)
fig1.append_trace(trace3, 1,1)
fig1.append_trace(trace4, 1,1)
fig1.append_trace(trace5, 1,1)

fig1['layout'].update( height=900,title='Time Series Max_DS provincia di MI', showlegend=False)

fig1.show()
# Out:
# <div>
#
#
#             <div id="b965fd1f-9a71-4a07-a9ac-5be5e70c83da" class="plotly-graph-div" style="height:900px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b965fd1f-9a71-4a07-a9ac-5be5e70c83da")) {
#                     Plotly.newPlot(
#                         'b965fd1f-9a71-4a07-a9ac-5be5e70c83da',
#                         [{"line": {"color": "#17BECF"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-23T00:00:00", "2019-12-23T03:00:00", "2019-12-23T06:00:00", "2019-12-23T09:00:00", "2019-12-23T12:00:00", "2019-12-23T15:00:00", "2019-12-23T18:00:00", "2019-12-23T21:00:00", "2019-12-24T00:00:00", "2019-12-24T03:00:00", "2019-12-24T06:00:00", "2019-12-24T09:00:00", "2019-12-24T12:00:00", "2019-12-24T15:00:00", "2019-12-24T18:00:00", "2019-12-24T21:00:00", "2019-12-25T00:00:00", "2019-12-25T03:00:00", "2019-12-25T06:00:00", "2019-12-25T09:00:00", "2019-12-25T12:00:00", "2019-12-25T15:00:00", "2019-12-25T18:00:00", "2019-12-25T21:00:00", "2019-12-26T00:00:00", "2019-12-26T03:00:00", "2019-12-26T06:00:00", "2019-12-26T09:00:00", "2019-12-26T12:00:00", "2019-12-26T15:00:00", "2019-12-26T18:00:00", "2019-12-26T21:00:00", "2019-12-27T00:00:00", "2019-12-27T03:00:00", "2019-12-27T06:00:00", "2019-12-27T09:00:00", "2019-12-27T12:00:00", "2019-12-27T15:00:00", "2019-12-27T18:00:00", "2019-12-27T21:00:00", "2019-12-28T00:00:00", "2019-12-28T03:00:00", "2019-12-28T06:00:00", "2019-12-28T09:00:00", "2019-12-28T12:00:00", "2019-12-28T15:00:00", "2019-12-28T18:00:00", "2019-12-28T21:00:00", "2019-12-29T00:00:00", "2019-12-29T03:00:00", "2019-12-29T06:00:00", "2019-12-29T09:00:00", "2019-12-29T12:00:00", "2019-12-29T15:00:00", "2019-12-29T18:00:00", "2019-12-29T21:00:00"], "xaxis": "x", "y": [520.1049, 9.8933, 0.0, 102.8237, 1638.4983, 949.3467, 2545.6805, 26665.572500000002, 3306.0874999999996, 0.0, 30.3979, 222.3551, 4901.034099999999, 8146.9801, 4628.405199999999, 6562.3637, 407.5237, 0.0, 19.2472, 397.90430000000003, 105.2313, 386.1083, 4697.1024, 24798.825599999996, 1278.7666, 0.0, 0.0, 149.5949, 1505.8585, 2618.0574, 8584.5907, 19227.1232, 897.0500000000001, 0.0, 0.0, 671.9388, 2038.8078999999998, 2799.2914, 2714.4844000000003, 23457.400999999998, 551.6479, 0.0, 0.0, 0.0, 1051.3091, 2510.7911, 2846.3352999999997, 24502.1371, 1768.9321, 0.0, 0.0, 93.1945, 1957.6602000000003, 2930.1028000000006, 4899.839, 21283.9902], "yaxis": "y"}, {"line": {"color": "#7F7F7F"}, "name": "SUM(MAX_DS)", "opacity": 0.8, "type": "scatter", "x": ["2019-12-30T00:00:00", "2019-12-30T03:00:00", "2019-12-30T06:00:00", "2019-12-30T09:00:00", "2019-12-30T12:00:00", "2019-12-30T15:00:00", "2019-12-30T18:00:00", "2019-12-30T21:00:00", "2019-12-31T00:00:00", "2019-12-31T03:00:00", "2019-12-31T06:00:00", "2019-12-31T09:00:00", "2019-12-31T12:00:00", "2019-12-31T15:00:00", "2019-12-31T18:00:00", "2019-12-31T21:00:00", "2020-01-01T00:00:00", "2020-01-01T03:00:00", "2020-01-01T06:00:00", "2020-01-01T09:00:00", "2020-01-01T12:00:00", "2020-01-01T15:00:00", "2020-01-01T18:00:00", "2020-01-01T21:00:00", "2020-01-02T00:00:00", "2020-01-02T03:00:00", "2020-01-02T06:00:00", "2020-01-02T09:00:00", "2020-01-02T12:00:00", "2020-01-02T15:00:00", "2020-01-02T18:00:00", "2020-01-02T21:00:00", "2020-01-03T00:00:00", "2020-01-03T03:00:00", "2020-01-03T06:00:00", "2020-01-03T09:00:00", "2020-01-03T12:00:00", "2020-01-03T15:00:00", "2020-01-03T18:00:00", "2020-01-03T21:00:00", "2020-01-04T00:00:00", "2020-01-04T03:00:00", "2020-01-04T06:00:00", "2020-01-04T09:00:00", "2020-01-04T12:00:00", "2020-01-04T15:00:00", "2020-01-04T18:00:00", "2020-01-04T21:00:00", "2020-01-05T00:00:00", "2020-01-05T03:00:00", "2020-01-05T06:00:00", "2020-01-05T09:00:00", "2020-01-05T12:00:00", "2020-01-05T15:00:00", "2020-01-05T18:00:00", "2020-01-05T21:00:00"], "xaxis": "x", "y": [1016.8185, 332.1583, 0.0, 0.0, 747.8939999999999, 1104.7071, 3012.9500000000003, 24883.840100000005, 7922.9430999999995, 0.0, 0.0, 92.2235, 4027.5224999999996, 9109.752700000001, 3360.3019, 611.0487, 306.935, 0.0, 0.0, 25.4368, 214.75100000000003, 3578.3886, 4971.4747, 23820.771599999996, 832.0942, 0.0, 0.0, 18.3433, 628.6456, 1303.429, 4151.1053, 25510.943600000002, 304.4262, 0.0, 0.0, 0.0, 781.5186, 568.5023, 4309.827399999999, 27007.995000000003, 1438.7325, 0.0, 0.0, 72.00800000000001, 1039.89160000000 ...
